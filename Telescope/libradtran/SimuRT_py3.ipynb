# %% [markdown]
# # Example if call LibRadTran from the notebook
# =======================================================================
#
# - Sylvie Dagoret-Campagne
# - update 15 May 2018
#
#
#
# Simple test to call on-line libradtran to check if it is working

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
import os

# %%
from scipy.interpolate import interp1d

# %%
from librtsimana import *
from libsimulateTranspCTIOScattAbsAer3 import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
airmasses=np.linspace(1.,2.,20.)
pressure = 782.5
pwv=4.0
aer=0
ozone=300.
# Out:
# /sps/lsst/software/lsst_sims/sims_2_7_0/python/miniconda3-4.3.21/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   """Entry point for launching an IPython kernel.

# %%
NBOBS=len(airmasses)

# %%
all_transmission=np.zeros((NBWL,NBOBS))

# %%
idx=0
for am in airmasses:
    path,thefile=ProcessSimulationaer(am,pwv,ozone,aer,pressure) 
    data = np.loadtxt(os.path.join(path,thefile))
    wl = data[:,0]
    atm = data[:,1]  
    func=interp1d(wl,atm,kind='linear') 
    transm=func(WL)
    all_transmission[:,idx]=transm
    idx+=1

# %%
idx=0
for am in airmasses:
    plt.plot(WL,2.5*np.log10(all_transmission[:,idx]))
    idx+=1
plt.xlabel("$\lambda$ (nm)")
plt.ylabel("Atmospheric attenuation   (mag)")
plt.title("Atmospheric attenuation")
plt.ylim(-1.,0.)
plt.grid()

# %%
thetitle='Atmospheric attenuation 400-600 nm'

# %%
x1,y1,err1=FitAttenuationSmoothBin(airmasses,all_transmission,thetitle,ZMIN=400.,ZMAX=600.,Wwidth=11,Bwidth=10,Mag=True)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-11-e5321ed8341c> in <module>()
# ----> 1 x1,y1,err1=FitAttenuationSmoothBin(airmasses,all_transmission,thetitle,ZMIN=400.,ZMAX=600.,Wwidth=11,Bwidth=10,Mag=True)
#
# /pbs/throng/lsst/users/dagoret/lsst_sims/sims_maf_contrib/sims_lsst_rt/Telescope/libradtran/librtsimana.py in FitAttenuationSmoothBin(airmasses, transmissions, thetitle, ZMIN, ZMAX, Wwidth, Bwidth, Mag, showFlag)
#     201         transm=transmissions[:,idx_obs]
#     202
# --> 203         tr_smooth=smooth(transm,window_len=Wwidth)
#     204
#     205
#
# /pbs/throng/lsst/users/dagoret/lsst_sims/sims_maf_contrib/sims_lsst_rt/Telescope/libradtran/librtsimana.py in smooth(x, window_len, window)
#     101     #return y
#     102     if len(x)%2==0: # even case
# --> 103         return y[(window_len/2):-(window_len/2)]
#     104     else:           #odd case
#     105         return y[(window_len/2-1):-(window_len/2)]
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
thetitle='Atmospheric attenuation 600-1000 nm'

# %%
x2,y2,err2=FitAttenuationSmoothBin(airmasses,all_transmission,thetitle,ZMIN=600.,ZMAX=1000.,Wwidth=11,Bwidth=10,Mag=True)

# %%
wl=np.concatenate((x1,x2))
y=np.concatenate((y1,y2))
err=np.zeros(len(y))

# %%
PlotOpticalThroughput(wl,y,err,"reconstructed TOA")

# %% [markdown]
# ## Save simulation

# %%
np.savetxt('transmission.txt',all_transmission)
